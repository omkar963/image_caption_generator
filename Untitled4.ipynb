# %% [markdown]
# <a href="https://colab.research.google.com/github/omkar963/image_caption_generator/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kagglehub

# %%
import kagglehub
kagglehub.login()

# %%
from google.colab import files
files.upload()  # select kaggle.json
# !mkdir ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-983be12a-6ad2-4efd-bf37-f127b1553775" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-983be12a-6ad2-4efd-bf37-f127b1553775">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
import numpy as np
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, Dropout, add
from tensorflow.keras.utils import to_categorical, plot_model
import pickle
from tqdm import tqdm
from PIL import Image

# %%
import pandas as pd

CAPTION_FILE = ''  # adjust path if needed
df = pd.read_csv(CAPTION_FILE)
df.head()

Optional: build a dictionary {image_name: [list of captions]}
from collections import defaultdict
captions_dict = defaultdict(list)
for idx, row in df.iterrows():
    captions_dict[row['image_name']].append(row['caption'])
# Out:
#   File "/tmp/ipython-input-1655945401.py", line 7
#     Optional: build a dictionary {image_name: [list of captions]}
#                     ^
# SyntaxError: invalid syntax

# %%
import kagglehub

# Download latest version of the Flickr8k dataset
path = kagglehub.dataset_download("adityajn105/flickr8k")

print("Path to dataset files:", path)

# %%
model_vgg = VGG16(weights='imagenet')
model_cnn = Model(inputs=model_vgg.inputs, outputs=model_vgg.layers[-2].output)

IMAGE_DIR = '/content/data/images/'
def extract_features(img_path, model):
    img = load_img(img_path, target_size=(224,224))
    img_array = img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)
    feature = model.predict(img_array, verbose=0)
    return feature

features = {}
for img_name in tqdm(os.listdir(IMAGE_DIR)):
    img_path = os.path.join(IMAGE_DIR, img_name)
    features[img_name] = extract_features(img_path, model_cnn)

# Save features for faster training later
np.save('image_features.npy', features)

# %%
all_captions = []
for caps in captions_dict.values():
    for cap in caps:
        all_captions.append(cap)

tokenizer = Tokenizer(num_words=5000, oov_token='UNK')
tokenizer.fit_on_texts(all_captions)

# Save tokenizer for later use in backend
with open('tokenizer.pkl', 'wb') as f:
    pickle.dump(tokenizer, f)

vocab_size = len(tokenizer.word_index) + 1
max_length = max(len(cap.split()) for cap in all_captions)
print("Vocabulary Size:", vocab_size)
print("Max caption length:", max_length)

# %%
def create_sequences(tokenizer, max_length, captions_dict, features, vocab_size):
    X1, X2, y = [], [], []
    for img_name, caps in captions_dict.items():
        feature = features[img_name]
        for cap in caps:
            seq = tokenizer.texts_to_sequences([cap])[0]
            for i in range(1, len(seq)):
                in_seq, out_seq = seq[:i], seq[i]
                in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
                out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
                X1.append(feature.flatten())
                X2.append(in_seq)
                y.append(out_seq)
    return np.array(X1), np.array(X2), np.array(y)

X1, X2, y = create_sequences(tokenizer, max_length, captions_dict, features, vocab_size)
print("X1 shape:", X1.shape)
print("X2 shape:", X2.shape)
print("y shape:", y.shape)

# %%
inputs1 = Input(shape=(4096,))
fe1 = Dropout(0.5)(inputs1)
fe2 = Dense(256, activation='relu')(fe1)

# Sequence input
inputs2 = Input(shape=(max_length,))
se1 = Embedding(vocab_size, 256, mask_zero=True)(inputs2)
se2 = Dropout(0.5)(se1)
se3 = LSTM(256)(se2)

# Decoder (combine)
decoder1 = add([fe2, se3])
decoder2 = Dense(256, activation='relu')(decoder1)
outputs = Dense(vocab_size, activation='softmax')(decoder2)

model = Model(inputs=[inputs1, inputs2], outputs=outputs)
model.compile(loss='categorical_crossentropy', optimizer='adam')
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3858482226.py in <cell line: 0>()
#       4
#       5 # Sequence input
# ----> 6 inputs2 = Input(shape=(max_length,))
#       7 se1 = Embedding(vocab_size, 256, mask_zero=True)(inputs2)
#       8 se2 = Dropout(0.5)(se1)
#
# NameError: name 'max_length' is not defined

# %%
model.fit([X1, X2], y, epochs=10, batch_size=64)

# Save the trained model
model.save('model_weights.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-777149917.py in <cell line: 0>()
# ----> 1 model.fit([X1, X2], y, epochs=10, batch_size=64)
#       2
#       3 # Save the trained model
#       4 model.save('model_weights.h5')
#
# NameError: name 'model' is not defined
